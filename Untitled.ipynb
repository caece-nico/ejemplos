# %%
import pandas as pd
import matplotlib.pyplot as pt
print('Cargados')
# Out:
# Cargados

# %%
##cargamos el archivo .csv
datos = pd.read_csv('C:\\countries of the world.csv', sep = ',')
print(type(datos))
print(len(datos))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 227

# %%
datos.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
popu = datos.iloc[7:15,0:8]

# %%
popu
# Out:
#                Country                               Region  Population  \
# 7   Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 9             Armenia                  C.W. OF IND. STATES      2976372
# 10              Aruba               LATIN AMER. & CARIB           71891
# 11          Australia   OCEANIA                                20264082
# 12            Austria   WESTERN EUROPE                          8192880
# 13         Azerbaijan                  C.W. OF IND. STATES      7961619
# 14       Bahamas, The               LATIN AMER. & CARIB          303770
#
#     Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 7              443                      156,0                        34,54
# 8          2766890                       14,4                         0,18
# 9            29800                       99,9                         0,00
# ...

# %%
datos.set_index('Country', inplace = True)

# %%
datos.head()
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
#
#                  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                       48,0
# Albania                   28748                      124,6
# Algeria                 2381740                       13,8
# American Samoa              199                      290,4
# Andorra                     468                      152,1
#
#                 Coastline (coast/area ratio) Net migration  \
# Country
# Afghanistan                             0,00         23,06
# Albania                                 1,26         -4,93
# ...

# %%
datos.index.get_values()
# Out:
# array(['Afghanistan ', 'Albania ', 'Algeria ', 'American Samoa ',
#        'Andorra ', 'Angola ', 'Anguilla ', 'Antigua & Barbuda ',
#        'Argentina ', 'Armenia ', 'Aruba ', 'Australia ', 'Austria ',
#        'Azerbaijan ', 'Bahamas, The ', 'Bahrain ', 'Bangladesh ',
#        'Barbados ', 'Belarus ', 'Belgium ', 'Belize ', 'Benin ',
#        'Bermuda ', 'Bhutan ', 'Bolivia ', 'Bosnia & Herzegovina ',
#        'Botswana ', 'Brazil ', 'British Virgin Is. ', 'Brunei ',
#        'Bulgaria ', 'Burkina Faso ', 'Burma ', 'Burundi ', 'Cambodia ',
#        'Cameroon ', 'Canada ', 'Cape Verde ', 'Cayman Islands ',
#        'Central African Rep. ', 'Chad ', 'Chile ', 'China ', 'Colombia ',
#        'Comoros ', 'Congo, Dem. Rep. ', 'Congo, Repub. of the ',
#        'Cook Islands ', 'Costa Rica ', "Cote d'Ivoire ", 'Croatia ',
#        'Cuba ', 'Cyprus ', 'Czech Republic ', 'Denmark ', 'Djibouti ',
#        'Dominica ', 'Dominican Republic ', 'East Timor ', 'Ecuador ',
# ...

# %%
datos.rename(columns={'Population':'populationss'}, inplace=True)

# %%
datos.columns
# Out:
# Index(['Region', 'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
#        'Coastline (coast/area ratio)', 'Net migration',
#        'Infant mortality (per 1000 births)', 'GDP ($ per capita)',
#        'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)',
#        'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
#        'Industry', 'Service'],
#       dtype='object')

# %%
datos.head()
# Out:
#                                               Region populationss  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)              31056997
# Albania          EASTERN EUROPE                           3581655
# Algeria          NORTHERN AFRICA                         32930091
# American Samoa   OCEANIA                                    57794
# Andorra          WESTERN EUROPE                             71201
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                       48,0
# Albania                  28748                      124,6
# Algeria                2381740                       13,8
# American Samoa             199                      290,4
# Andorra                    468                      152,1
#
#                 Coastline (coast/area ratio) Net migration  \
# Country
# Afghanistan                             0,00         23,06
# Albania                                 1,26         -4,93
# ...

# %%
datos.loc['Albania ':'Andorra ',['Region','Climate','Birthrate']]
# Out:
#                                               Region Climate Birthrate
# Country
# Albania          EASTERN EUROPE                            3     15,11
# Algeria          NORTHERN AFRICA                           1     17,14
# American Samoa   OCEANIA                                   2     22,46
# Andorra          WESTERN EUROPE                            3      8,71

# %%
datos['Region'].unique()
# Out:
# array(['ASIA (EX. NEAR EAST)         ',
#        'EASTERN EUROPE                     ',
#        'NORTHERN AFRICA                    ',
#        'OCEANIA                            ',
#        'WESTERN EUROPE                     ',
#        'SUB-SAHARAN AFRICA                 ', 'LATIN AMER. & CARIB    ',
#        'C.W. OF IND. STATES ', 'NEAR EAST                          ',
#        'NORTHERN AMERICA                   ',
#        'BALTICS                            ', 'POP'], dtype=object)

# %%
datos.groupby(['Region','Climate'])['populationss'].sum()
# Out:
# Region                               Climate
# ASIA (EX. NEAR EAST)                 1           268381214
#                                      1,5        1313973713
#                                      2           782564714
#                                      2,5        1095351995
#                                      3           199423453
# BALTICS                              3             3599068
# C.W. OF IND. STATES                  1            40311673
#                                      2             7320815
#                                      2,5           5213898
#                                      3            51372289
#                                      4            28502627
# EASTERN EUROPE                       3            99514234
#                                      4             4498976
# LATIN AMER. & CARIB                  1,5         144741174
#                                      2           357595441
# ...

# %%
datos.reset_index(inplace = True)

# %%
datos.head()
# Out:
#            Country                               Region populationss  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)              31056997
# 1         Albania   EASTERN EUROPE                           3581655
# 2         Algeria   NORTHERN AFRICA                         32930091
# 3  American Samoa   OCEANIA                                    57794
# 4         Andorra   WESTERN EUROPE                             71201
#
#   Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0         647500                       48,0                         0,00
# 1          28748                      124,6                         1,26
# 2        2381740                       13,8                         0,04
# 3            199                      290,4                        58,29
# 4            468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births) GDP ($ per capita)  \
# ...

# %%
## queremos ver los paises con clima c(2,3) y population > 550000
seleccion = datos[datos['Climate'] == '3']

# %%
seleccion
# Out:
#              Country                               Region populationss  \
# 1           Albania   EASTERN EUROPE                           3581655
# 4           Andorra   WESTERN EUROPE                             71201
# 8         Argentina               LATIN AMER. & CARIB         39921833
# 12          Austria   WESTERN EUROPE                           8192880
# 19          Belgium   WESTERN EUROPE                          10379067
# 30         Bulgaria   EASTERN EUROPE                           7385367
# 37       Cape Verde   SUB-SAHARAN AFRICA                        420979
# 41            Chile               LATIN AMER. & CARIB         16134219
# 52           Cyprus   NEAR EAST                                 784301
# 53   Czech Republic   EASTERN EUROPE                          10235455
# 54          Denmark   WESTERN EUROPE                           5450661
# 64          Estonia   BALTICS                                  1324333
# ...
